# %% [markdown]
# # CH01.2. **Sets**

# %% [markdown]
# > ## **집합(Set)**

# %% [markdown]
# #### **(1) 정의** : 어떤 아이템, 객체 혹은 **요소**(원소)들의 모음

# %% [markdown]
# #### **(2) 예시** :
# #### $ \hspace{0.15cm} $ ① 집합 $ A = \{ 😀, 😡 \} $
# #### $ \hspace{0.15cm} $ ② 집합 $ B  = \{ 1, 2, 3, 4 \} $

# %% [markdown]
# #### **(`PLUS`)** 집합에서 요소들은 순서(order)가 존재하지 않음 $ \, \{ 😀,\, 😡 \} = \{ 😡,\, 😀 \} $

# %% [markdown]
# #### **(3) 포함 관계** :
# #### $ \hspace{0.15cm} $ 집합 $ A = \{ 😀,\, 😡 \} $ 와 집합 $ B = \{ 😀,\, 😡,\, 🥹 \} $ 가 존재할 때
# #### $ \hspace{0.15cm} $ ① 요소 😀가 집합 $ A $ 에 속한다. $ \, \Rightarrow{} \, 😀 \in{} A $
# #### $ \hspace{0.15cm} $ ② 요소 😭가 집합 $ A $ 에 속하지 않는다. $ \, \Rightarrow{} \, 😭 \notin{} A $

# %% [markdown]
# #### **(4) 수의 체계 집합 표현** :
# #### $ \hspace{0.15cm} $ ① 자연수(natural number) : $ \, \mathbb{N} = \{ 1, 2, 3, \cdots{} \} $
# #### $ \hspace{0.15cm} $ ② 정수(integer) : $ \, \mathbb{Z} = \{ \cdots{}, -1, 0, 1, 2, 3, \cdots{} \} $
# #### $ \hspace{0.15cm} $ ③ 유리수(rational number) : $ \, \mathbb{Q} = \{ p/q \; | \; p \in{} \mathbb{Z}, q \in{} \mathbb{N} \} = \{ \cdots{} , -{{2}\over{6}}, \cdots{}, 0, \cdots{}, {{2}\over{5}}, \cdots{} \}$
# #### $ \hspace{0.15cm} $ ④ 실수(real number) : $ \, \mathbb{R} = \{ \cdots{}, -1, -0.001, -0.1, 0, 1, \cdots{}, \pi{}, \cdots{} \} $

# %% [markdown]
# #### **(5) 간격의 집합 표현** :
# #### $ \hspace{0.15cm} $ ① 열린 구간(open interval) : $ (a,\, b) = \{ x \; | \; a < x < b \} $
# #### $ \hspace{0.15cm} $ ② 닫힌 구간(closed interval) : $ [a,\, b] = \{ x \; | \; a \leq{} x \leq{} b \} $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **부분집합(Subset)**

# %% [markdown]
# #### **(1) 정의** : 집합 $ \, A $ 의 모든 요소가 집합 $ \, B $ 에도 존재할 때의 집합 $ \, B $
# #### $ \Rightarrow{} A \subset{} B $

# %% [markdown]
# #### **(2) 포함관계** :
# #### $ \hspace{0.15cm} $ 집합 $ A = \{ 😀,\; 😡 \} $ 와 집합 $ B = \{ 😀,\; 😡,\; 🥹 \} $ 가 존재할 때,
# #### $ \hspace{0.15cm} $ ① $ A $ 는 $ B $의 부분집합이다. $ \; \Rightarrow{} \; A \subset{} B $
# #### $ \hspace{0.15cm} $ ② $ B $ 는 $ A $의 부분집합이 아니다. $ \; \Rightarrow{} \; B \not\subset{} A $

# %% [markdown]
# #### **(`PLUS`)** 이 때 $ B $ 를 $ A $의 초집합(superset)이라고 정의함

# %% [markdown]
# #### **(`PLUS`)** 만약 두 집합이 같다면, 두 집합은 동치(equivalent)하다고 하고, 기호 "$ = $" 을 사용

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **공집합(Empty set; Null set)**

# %% [markdown]
# #### **(1) 정의** : 요소를 하나도 갖지 않는 집합
# #### $ \Rightarrow{} \emptyset{} = \{ \} $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **벤 다이어그램(Venn Diagram)**

# %% [markdown]
# #### **(1) 정의** : 두 개 이상 집합 간의 논리적 관계를 표현하는 시각적 도구

# %% [markdown]
# #### **(2) 예시** :
# #### $ \hspace{0.15cm} $ ① $ S = \{1, 2, 3 \}, \;\; A = \{ 1 \} \subset{} S $
# <img src="../../img/01.2. Sets (1).png" width="30%" height="30%"></img>
# #### $ \hspace{0.15cm} $ ② $ A \subset{} B \subset{} S $
# <img src="../../img/01.2. Sets (2).png" width="30%" height="30%"></img>

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **집합 연산(Set Opearation)**

# %% [markdown]
# #### **(1) 합집합(Union)** : 두 집합의 모든 원소를 포함하는 집합 $ \; \Rightarrow{} \; A \cup{} B $
# #### $ \hspace{0.15cm} A = \{ 1, 2, 3 \}, \;\; B = \{ 1, 4, 5 \}, \;\; A \cup{} B = \{ 1, 2, 3, 4, \; 5 \} $
# <img src="../../img/01.2. Sets (3).png" width="30%" height="30%"></img>

# %% [markdown]
# #### **(`PLUS`)** $ A_{1} \cup{} A_{2} \cup{} A_{3} \cup{} A_{4} \cdots{} \cup A_{n} = \cup{}_{i=1}^{n} A_{i} $

# %% [markdown]
# #### **(2) 교집합(Intersection)** : 두 집합의 공통 요소를 포함하는 집합 $ \; \Rightarrow{} \; A \cap{} B $
# #### $ \hspace{0.15cm} A = \{ 1, 2, 3 \}, \;\; B = \{ 1, 4, 5 \}, \;\; A \cap{} B = \{ 1 \} $
# <img src="../../img/01.2. Sets (4).png" width="30%" height="30%"></img>

# %% [markdown]
# #### **(`PLUS`)** $ A_{1} \cap{} A_{2} \cap{} A_{3} \cap{} A_{4} \cdots{} \cap A_{n} = \cap{}_{i=1}^{n} A_{i} $

# %% [markdown]
# #### **(3) 여집합(Complement)** : 전체 집합 중 특정 집합의 요소를 제외한 집합 $ \; \Rightarrow{} \; A^{c} $
# #### $ \hspace{0.15cm} S = \{ 1, 2, 3, 4, 5 \}, \;\; A = \{ 1, 2, 3 \}, \;\; A^{c} = \{ 4, 5 \} $
# <img src="../../img/01.2. Sets (5).png" width="30%" height="30%"></img>

# %% [markdown]
# #### **(4) 차집합(Subtraction ; Difference)** : 한 집합에서 다른 집합의 요소를 제외한 집합 $ \; \Rightarrow{} \; A - B = A \cap{} B^{c} $
# #### $ \hspace{0.15cm} $ $ A = \{ 1, 2, 3 \}, \;\; B = \{ 1, 4, 5 \}, \;\; A \cap{} B = \{ 2, 3 \} $
# <img src="../../img/01.2. Sets (6).png" width="30%" height="30%"></img>

# %% [markdown]
# #### **(5) 서로소 집합(Disjoint)** : 두 집합이 공통된 요소를 갖지 않을 때의 집합 $ \; \Rightarrow{} \; A \cap{} B = \empty{} $
# #### $ \hspace{0.15cm} $ $ A = \{ 1, 2, 3 \}, \;\; B = \{ 6, 8 \}, \;\; A \cap{} B = \empty{} $
# <img src="../../img/01.2. Sets (7).png" width="30%" height="30%"></img>

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **분할(Partition)**

# %% [markdown]
# #### **(1) 정의** : 공집합이 아니면서 **여러 개의 집합의 합을 통해 특정 집합이 되는** 부분 집합
# #### $ \Rightarrow{} A = \cup{}^{n}_{i=1}A_{i} $
# <img src="../../img/01.2. Sets (8).png" width="30%" height="30%"></img>

# %% [markdown]
# #### **(2) 예시** :
# #### $ \hspace{0.15cm} $ ① **[CONTENTS]**
# #### $ \hspace{0.5cm} A = \{ 1,\; 2,\; 3,\; 4,\; 5 \},\; A_{1} = \{ 1 \},\; A_{2} = \{ 2,\; 4 \},\; A_{3} = \{ 3,\; 5 \} $
# #### $ \hspace{0.5cm} A_{1} \cup{} A_{2} \cup{} A_{3} = \cup{}^{3}_{i=1}A_{i} = A = \{ 1,\; 2,\; 3,\; 4,\; 5 \} $
# #### $ \hspace{0.15cm} $ ② **[CONTENTS]**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## (Theorem 1-1) **De Morgan's Law**

# %% [markdown]
# #### 논리 연산에서 논리합(OR)은 논리곱(AND)과 부정기호(NOT)로, 논리곱은 논리합과 부정기호로 표현할 수 있다.
# #### **(1)** $ ( \cup{}_{i=1}^{n} A_{i} )^{c} = \cap{}_{i=1}^{n} A_{i}^{c} $
# <p align="center">
#     <img src="../../png/01.2. Sets (9).png" align="center" width="25%" height="25%"></img>
#     <img src="../../png/01.2. Sets (10).png" align="center" width="25%" height="25%"></img>
#     <img src="../../png/01.2. Sets (11).png" align="center" width="25%" height="25%"></img>
# </p>

# %% [markdown]
# #### **(2)** $ ( \cap{}_{i=1}^{n} A_{i} )^{c} = \cup{}_{i=1}^{n} A_{i}^{c} $
# <p align="center">
#     <img src="../../png/01.2. Sets (9).png" align="center" width="25%" height="25%"></img>
#     <img src="../../png/01.2. Sets (10).png" align="center" width="25%" height="25%"></img>
#     <img src="../../png/01.2. Sets (12).png" align="center" width="25%" height="25%"></img>
# </p>

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## (Theorem 1-2) **Distributive Law of set**

# %% [markdown]
# #### 집합 $ \; A,\; B,\; C $ 가 존재할 때 아래의 식이 성립한다.
# #### **(1)** $ A \cap{} ( B \cup{} C ) = ( A \cap{} B ) \cup{} ( A \cap{} C ) $
# #### **(2)** $ A \cup{} ( B \cap{} C ) = ( A \cup{} B ) \cap{} ( A \cup{} C ) $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **곱집합(Product Set)**

# %% [markdown]
# #### **(1) 정의** : 두 개 이상의 집합에서 요소를 하나씩 뽑아 만든 모든 **순서쌍**의 집합

# %% [markdown]
# #### **(2) 예시 :**
# #### $ \hspace{0.15cm} $ ① 집합 $ A = \{ 1,\; 2 \},\; B = \{ a,\; b,\; c \} $ 가 존재할 때
# #### $ \hspace{0.45cm} $ $ A \times{} B = \{ (1,a),\; (1,b),\; (1,c),\; (2,a),\; (2,b),\; (2,c) \} $
# #### $ \hspace{0.45cm} $ $ B \times{} A = \{ (a,1),\; (a,2),\; (b,1),\; (b,2),\; (c,1),\; (c,2) \} $

# %% [markdown]
# #### **(`PLUS`)** 곱집합은 원소의 순서를 고려하기 때문에 $ \, (1,a) \neq{} (a,1) $ 이고, $ \, A \times{} B \neq{} B \times{} A $

# %% [markdown]
# #### $ \hspace{0.15cm} $ ② $ \mathbb{R} \times{} \mathbb{R} = \{ (x,\; y) \; | \; x \in \mathbb{R},\; y \in \mathbb{R} \} = \mathbb{R}^{2} $ (space)

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **가산 집합(Countable set)**

# %% [markdown]
# #### **(1) 정의** : 집합의 요소들을 자연수와 일대일 대응(one-to-one correspondence)할 수 있는 집합

# %% [markdown]
# #### **(`PLUS`)** 집합의 요소들을 자연수와 일대일 대응할 수 없는 경우, 불가산 집합(uncountable set)이라고 정의함

# %% [markdown]
# #### **(3) 예시** :
# #### $ \hspace{0.15cm} $ ① 유한 집합(finite set) : $ A = \{ 1,\; 2 \},\; B = \{ a,\; b,\; c \},\; \cdots{} $
# #### $ \hspace{0.15cm} $ ② 무한 집합(inifinite)이고 가산할 수 있는(countable) 집합 : $ \; \mathbb{N} $ (자연수), $ \; \mathbb{Z} $ (정수), $ \; \mathbb{Q} $ (유리수)
# #### $ \hspace{0.15cm} $ ③ 무한 집합(inifinite)이고 가산할 수 없는(uncountable) 집합 : $ \; \mathbb{R} $ (실수)

# %% [markdown]
# #### **(`WHY?`)** 유리수 집합이 가산 집합인 이유
# #### http://www.math.cmu.edu/~wgunther/127m12/notes/CSB.pdf

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## (Theorem 1-3) **가산 집합과 부분 집합의 관계**

# %% [markdown]
# #### **(1)** 가산 집합의 부분 집합은 가산 집합이다.

# %% [markdown]
# #### **(2)** 불가산 집합의 구간(부분 집합)은 불가산 집합이다.

# %% [markdown]
# #### **(3)** 불가산 집합의 초집합은 불가산 집합이다.

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## (Theorem 1-4) **가산 집합과 집합 연산의 관계**

# %% [markdown]
# #### **(1)** 집합 $ A_{1}, \; A_{2}, \; \cdots{} $ 가 가산 집합이면, 이 집합들의 합집합도 가산 집합이다.

# %% [markdown]
# #### **(2)** 두 집합이 가산 집합이면, 두 집합의 곱집합도 가산 집합이다.

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **집합의 크기(Cardinality)**

# %% [markdown]
# #### **(1) 정의** : 집합의 요소의 개수(사이즈)
# #### $ \Rightarrow{} \; | \{ a_{1},\; a_{2},\; \cdots{},\; a_{n} \} | = n $

# %% [markdown]
# #### **(2) 예시** :
# #### $ \hspace{0.15cm} $ ① 유한 집합(finite set)
# #### $ \hspace{0.15cm} $ $ |\{ 1,\; 2 \}| = 2,\; |\{ a,\; b,\; c \}| = 3,\; \cdots{} $
# #### $ \hspace{0.15cm} $ ② 무한 집합(inifinite)이고 가산할 수 있는(countable) 집합
# #### $ \hspace{0.15cm} $ $ |\mathbb{N}| = |\mathbb{Z}| = |\mathbb{Q}| = \aleph{},\; \cdots{} $
# #### $ \hspace{0.15cm} $ ③ 무한 집합(inifinite)이고 가산할 수 없는(uncountable) 집합
# #### $ \hspace{0.15cm} $ $ |\mathbb{R}| = 2^{\aleph{}},\; \cdots{} $

# %% [markdown]
# #### **(`PLUS`)** 집합론에서 $ \aleph{} $ (aleph null)는 가장 작은 무한수를 의미함

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## (Theorem 1-5) **포함배제의 원리(Inclusion-exclusion principle)**

# %% [markdown]
# #### **유한 집합**에서 여러 개의 합집합의 크기를 구할 때 아래와 같다.
# #### $ \Rightarrow{} | \cup{}_{i=1}^{n} A_{i} | = \sum{}_{i=1}^{n}|A_{i}| - \sum{}_{i<j}^{n}|A_{i}\cap{}A_{j}| + \sum_{i<j<k}^{n}|A_{i}\cap{}A_{j}\cap{}A_{k}| - \cdots{} + (-1)^{n+1}|\cap{}_{i=1}^{n}A_{i}| $
